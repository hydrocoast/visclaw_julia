# %% [markdown]
# # VisClaw.jl - examples of use
#
# <div style="text-align: right;"> verified on v0.3.1 in 2019</div>
# <div style="text-align: right;"> Takuya Miyashita (miyashita@hydrocoast.jp) </div>
#
# ## Load conditions and numerical results
# This process is the same as [Example 1](https://github.com/hydrocoast/visclaw_julia/blob/master/Example1_Plots.ipynb).

# %%
using VisClaw
using GMT: GMT
using PyPlot, Printf

simdir = joinpath(CLAW, "geoclaw/examples/tsunami/chile2010/_output")
topofile, ntopo = VisClaw.topodata(simdir)
topo = VisClaw.LoadTopo(topofile)

# check
println(typeof(topo))
println(fieldnames(typeof(topo)))
# Out:
# topotype is assumed as 2.
# VisClaw.Topo
# (:ncols, :nrows, :x, :y, :dx, :dy, :elevation)

# %% [markdown]
# ## Plot using GMT
# ### topo

# %%
# makegrd
G = VisClaw.geogrd(topo; V=true)

# makecpt
cpt = GMT.makecpt(; C=:earth, T="-7000/4500", D=true)

# commom options: projection J and region R
region = VisClaw.getR(topo)
proj = VisClaw.getJ("X10d", VisClaw.axesratio(topo))

# check
println("-J"*proj)
println("-R"*region)

# plot
GMT.grdimage(G, C=cpt, J=proj, R=region, Q=true, V=true)
GMT.colorbar!(J=proj, R=region, B="xa1000f1000 y+l\"(m)\"", D="jBR+w10.0/0.3+o-1.2/-0.1", V=true)
GMT.coast!(J=proj, R=region, D=:i, W=:thinnest, V=true)

# show
PS = GMT.fname_out(Dict())[1]
GMT.gmt("psbasemap -J$proj -R$region -Ba15f15 -BneSW -P -O >> $PS")
I = GMT.psconvert("-TG -E300 -A $PS")
PyPlot.imshow(I.image)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# -JX10.0d/10.0d
# -R-120.0/-60.0/-60.0/0.0
# PyObject <matplotlib.image.AxesImage object at 0x7f99e81e22e8>

# %% [markdown]
# ### dtopo

# %%
# dtopo
dtopofile, ntopo = VisClaw.dtopodata(simdir)
dtopo = VisClaw.LoadDeform(dtopofile)

# commom options: projection J and region R
region = VisClaw.getR(dtopo)
proj = VisClaw.getJ("X10d", VisClaw.axesratio(dtopo))

# check
println("-J"*proj)
println("-R"*region)

# makegrd
G = VisClaw.geogrd(dtopo; V=true)

# makecpt
cpt = GMT.makecpt(; C=:polar, T="-3.0/3.0", D=true)

# plot
GMT.grdimage(G, C=cpt, J=proj, R=region, B="", Q=true)
GMT.colorbar!(C=cpt, J=proj, R=region, B="xa1.0f1.0 y+l\"(m)\"", D="jBR+w10.0/0.3+o-1.5/0.0")
GMT.coast!(J=proj, R=region, D=:i, W="thinnest,gray20")
GMT.grdcontour!(G, J=proj, R=region, C=1, A=2, W=:black)


# show
PS = GMT.fname_out(Dict())[1]
GMT.gmt("psbasemap -J$proj -R$region -Ba5f5 -BneSW -P -O >> $PS")
I = GMT.psconvert("-TG -E300 -A $PS")
PyPlot.imshow(I.image)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# -JX10.0d/10.0d
# -R-77.0/-67.0/-40.0/-30.0
# PyObject <matplotlib.image.AxesImage object at 0x7f99e81038d0>

# %% [markdown]
# ### sea surface height

# %%
# load water surface height
amrall = VisClaw.LoadSurface(simdir, 1:5) # fort.q0000 to fort.q0004

# commom options: projection J and region R
region = VisClaw.getR(amrall.amr[1])
proj = VisClaw.getJ("X10d", VisClaw.axesratio(amrall.amr[1]))

# for land masking
landmask_txt = VisClaw.landmask_asc(topo)
Gland = VisClaw.landmask_grd(landmask_txt, R=region, I=topo.dx, S="$(sqrt(2.0)topo.dx)d")

# makecpt
cpt = GMT.makecpt(C=:polar, T="-1.0/1.0", D=true, V=true)


# snapshot: index 4
i = 4

    # step
    time_str = "+t"*@sprintf("%03d", amrall.timelap[i]/60.0)*"_min"

    # land-masked surface grids
    G = VisClaw.tilegrd_mask.(amrall.amr[i], landmask_txt; spacing_unit="d")

    # plot
    GMT.basemap(J=proj, R=region, B=time_str)
    GMT.grdimage!(Gland, R=region, J=proj, C="white,gray80", Q=true)
    GMT.grdimage!.(G, C=cpt, J=proj, R=region, B="", Q=true)
    GMT.colorbar!(C=cpt, J=proj, R=region, B="xa0.5f0.5 y+l(m)", D="jBR+w10.0/0.3+o-1.5/0.0", V=true)
    GMT.coast!(J=proj, R=region, D=:i, W=:thinnest, V=true)

# show
PS = GMT.fname_out(Dict())[1]
GMT.gmt("psbasemap -J$proj -R$region -Ba15f15 -BneSW -P -O >> $PS")
I = GMT.psconvert("-Tg -E300 -A $PS")
PyPlot.imshow(I.image)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x7f99c9b5ec88>

# %% [markdown]
# ### pressure and wind fields

# %%
# ike
simdir = joinpath(CLAW,"geoclaw/examples/storm-surge/ike/_output")
using Dates: Dates
timeorigin = Dates.DateTime(2008, 9, 13, 7)

# makecpt
cpt = GMT.makecpt(C=:wysiwyg, T="950/1020", D=true, I=true)

# load
amrall = VisClaw.LoadStorm(simdir)
VisClaw.RemoveCoarseUV!.(amrall.amr) # avoid to plot unnecessary arrows

# projection and region GMT
region = VisClaw.getR(amrall.amr[1])
proj = VisClaw.getJ("X10d", VisClaw.axesratio(amrall.amr[1]))

# time in string
time_dates = timeorigin .+ Dates.Second.(amrall.timelap)
time_str = Dates.format.(time_dates,"yyyy/mm/dd_HH:MM")

# arrow style
arrow = "0.01/0.15/0.05" # -A LineWidth/HeadLength/HeadSize
vscale = "e0.03/0.0/12"  # -Se <velscale> / <confidence> / <fontsize>
arrow_color = "black" # -G
scalefile = VisClaw.txtwind_scale(-92.5, 30.0, 30.0, 0.0) # for legend

# snapshot: index 7
i = 7

    # surface grids
    G = VisClaw.tilegrd.(amrall.amr[i]; spacing_unit="d")

    # plot pressure field
    GMT.basemap(J=proj, R=region, B="+t"*time_str[i])
    GMT.grdimage!.(G, C=cpt, J=proj, R=region, B="", Q=true)
    GMT.colorbar!(J=proj, R=region, B="xa10f10 y+lhPa", D="jBR+w8.0/0.3+o-1.5/0.0")
    GMT.coast!(J=proj, R=region, B="a10f10 neSW", D=:i, W="thinnest,gray80")

    # plot wind field
    psfile = GMT.fname_out(Dict())[1]
    velofile = VisClaw.txtwind(amrall.amr[i], skip=3)
    GMT.gmt("psvelo $velofile -J$proj -R$region -G$arrow_color -A$arrow -S$vscale -P -K -O >> $psfile ")
    GMT.gmt("psvelo $scalefile -J$proj -R$region -G$arrow_color -A$arrow -S$vscale -Y1.2d -P -O >> $psfile ")


# show
PS = GMT.fname_out(Dict())[1]
I = GMT.psconvert("-Tg -E300 -A $PS")
PyPlot.imshow(I.image)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x7f99c99cb7f0>
